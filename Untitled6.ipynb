# %% [markdown]
# <a href="https://colab.research.google.com/github/anudasgupta00/Colour-Identification-in-Images_OpenCV/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 
import cv2 as cv 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from google.colab.patches import cv2_imshow 
from PIL import Image 
from skimage import io 
img=io.imread("/content/toucan2044.jpg")
img=cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv2_imshow(img)
img=cv.cvtColor(img,cv.COLOR_RGB2HSV)
cv2_imshow(img)
lower_bound=np.array([50,20,20])
upper_bound=np.array([100,255,255])
mask=cv2.inRange(img,lower_bound,upper_bound)
cv2_imshow(mask)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FD1ADA964D0>
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FD1ADDC5D90>
# <PIL.Image.Image image mode=L size=1024x768 at 0x7FD1ADAB7B50>
